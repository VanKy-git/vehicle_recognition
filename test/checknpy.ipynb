# %%
import numpy as np

data = np.load("../data/features/X_test.npy")

print(data)
print(data.shape)
print(data.dtype)
# Out:
# [[ 9.58370864e-01  1.09695848e-02  1.25145968e-02 ...  2.31116330e+01
#    1.48415628e+01 -2.33860714e+01]
#  [ 9.50679660e-01  2.49744337e-02  1.16822556e-01 ...  2.00836773e+01
#    1.32892719e+01 -2.18511079e+01]
#  [ 1.91972535e-02  4.59652534e-03  1.64934136e-02 ... -1.95770880e+01
#   -1.33624155e+01 -2.01929421e+01]
#  ...
#  [ 9.43326890e-01  3.29834595e-03  8.24586488e-04 ... -1.95880368e+01
#    1.30863980e+01 -2.07580186e+01]
#  [ 9.19047534e-01  3.29999113e-03  5.15623624e-03 ...  2.20991143e+01
#    1.44307112e+01 -2.25985771e+01]
#  [ 9.76618350e-01  1.06803272e-02  1.53888585e-02 ...  2.15088523e+01
#    1.38419403e+01 -2.41277400e+01]]
# (1500, 545)
# float64
